# %%
import joblib
model = joblib.load('/Users/raashidkhan/Desktop/GitHub-Projects/MNIST_Classification/models/sgd_clf.pkl')
preds = model.predict(X_test)
print("Test accuracy:", accuracy_score(y_test_5, preds))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import joblib
#       2 model = joblib.load('/Users/raashidkhan/Desktop/GitHub-Projects/MNIST_Classification/models/sgd_clf.pkl')
# ----> 3 preds = model.predict(X_test)
#       4 print("Test accuracy:", accuracy_score(y_test_5, preds))
#
# NameError: name 'X_test' is not defined
