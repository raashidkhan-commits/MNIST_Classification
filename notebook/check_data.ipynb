# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %%
input_directory = Path('/Users/raashidkhan/Desktop/GitHub-Projects/MNIST_Classification/data')

# %%
X=pd.read_csv(input_directory/'mnist_data.csv').to_numpy()
y=pd.read_csv(input_directory/'mnist_target.csv').to_numpy()

# %%
plt.imshow(X[0].reshape(28,28),cmap='gray')

# %%
i=0
while i!=5:
    plt.imshow(X[i].reshape(28,28),cmap='gray')
    print("Label:",y[i])
    i=i+1
    plt.show()
# Out:
# Label: [0]
# Label: [4]
# Label: [1]
# Label: [9]
# Label: [2]
