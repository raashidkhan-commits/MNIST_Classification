# %%
def custom(a,b):
    print ('Sum of A & B is :',a+b)
    print ('Difference of A & B is :',a-b)
    return None

# %%
custom(29,35)
# Out:
# Sum of A & B is : 64
# Difference of A & B is : -6

# %%
a=[1,2,3,4,5]
b=[5,4,3,2,1]
print (a+b)
# Out:
# [1, 2, 3, 4, 5, 5, 4, 3, 2, 1]

# %%
import matplotlib.pyplot as plt
plt.plot(a,b)
plt.show()

# %%
{1,2,3,3,4,1}
# Out:
# {1, 2, 3, 4}

# %%
  wh0.1*0.2
# Out:
# 0.020000000000000004
